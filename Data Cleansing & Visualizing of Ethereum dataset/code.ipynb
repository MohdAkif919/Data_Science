# %%
#libraries to be use for analysis
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the csv file
data = pd.read_csv(r"C:\Users\mohda\Downloads\Ethereum Historical Data.csv")

# %%
# Displays starting 10 rows of dataset
data.head(10)
# Out:
#         Date   Open   High    Low  Close  Volume
# 0 2016-10-03  11.20  11.85  11.07  11.75       4
# 1 2016-11-03  11.75  11.95  11.75  11.95     179
# 2 2016-12-03  11.95  13.45  11.95  12.92     833
# 3 2016-03-13  12.92  15.07  12.92  15.07    1295
# 4 2016-03-14  15.07  15.07  11.40  12.50   92183
# 5 2016-03-15  12.63  13.42  11.98  13.06   39725
# 6 2016-03-16  13.06  13.89  12.62  12.88   19240
# 7 2016-03-17  12.58  12.61  10.44  10.74   89450
# 8 2016-03-18  11.09  11.20   8.34  10.74  157374
# 9 2016-03-19  10.97  11.10   9.78  10.31   67547

# %%
# Displays ending 10 rows of dataset
data.tail(10)
# Out:
#            Date     Open     High      Low    Close   Volume
# 2078 2021-11-17  4208.29  4298.30  4071.01  4290.88   664942
# 2079 2021-11-18  4290.31  4342.74  3958.44  4001.87   792376
# 2080 2021-11-19  3996.29  4305.41  3978.08  4295.43   571956
# 2081 2021-11-20  4295.27  4434.27  4206.75  4408.85   462992
# 2082 2021-11-21  4409.02  4422.60  4246.20  4268.08   446234
# 2083 2021-11-22  4268.07  4311.46  4026.75  4086.95   717082
# 2084 2021-11-23  4086.73  4384.75  4064.17  4340.23   684354
# 2085 2021-11-24  4340.23  4372.83  4172.19  4273.54   595963
# 2086 2021-11-25  4270.73  4549.74  4248.90  4520.30   578651
# 2087 2021-11-26  4520.30  4548.10  3917.43  4034.53  1004251

# %%
data.isnull().sum() #no null value present in any column
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
#basic information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2088 entries, 0 to 2087
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2088 non-null   object
#  1   Open    2088 non-null   float64
#  2   High    2088 non-null   float64
#  3   Low     2088 non-null   float64
#  4   Close   2088 non-null   float64
#  5   Volume  2088 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 98.0+ KB

# %%
data["Date"] = pd.to_datetime(data["Date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2088 entries, 0 to 2087
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2088 non-null   datetime64[ns]
#  1   Open    2088 non-null   float64
#  2   High    2088 non-null   float64
#  3   Low     2088 non-null   float64
#  4   Close   2088 non-null   float64
#  5   Volume  2088 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 98.0 KB

# %%
# %matplotlib inline
#Displays the total volume of ethereum for every year
total_vol = data.pivot_table(index=[data["Date"].dt.year],values="Volume",aggfunc="sum") 
display(high_vol)

#bar graph representation for the above analysis
total_vol.plot(kind="barh")
plt.ylabel("Year", fontsize = 15)
plt.title("Total Volume", fontsize = 15)
plt.show()
# Out:
#           Volume
# Date
# 2016    65253577
# 2017   225654034
# 2018  1668923802
# 2019  3683958971
# 2020  5177308840
# 2021   508494220

# %%
# %matplotlib inline
# Displays the data and bar chart of maximum opening, closing, highest and lowest price of ethereum for every year
max_data = data.pivot_table(index=[data["Date"].dt.year],values=["High","Open","Low","Close"],aggfunc="max")
display(max_data)

# Bar chart representation for the above analysis
max_data.plot(kind="bar",width=0.8)
plt.xlabel("Price (in $US)", fontsize = 15)
plt.ylabel("Year", fontsize = 15)
plt.title("Highest Price of Ethereum", fontsize = 15)
plt.show()
# Out:
#         Close     High      Low     Open
# Date
# 2016    20.70    21.69    18.44    20.86
# 2017   799.98   863.00   750.01   799.98
# 2018  1380.00  1423.20  1264.40  1379.90
# 2019   338.54   364.89   315.99   338.54
# 2020   751.80   757.11   724.67   751.92
# 2021  4808.38  4864.06  4715.43  4808.34

# %%
# %matplotlib inline
# Displays the data and bar chart of lowest opening, closing, highest and lowest price of ethereum for every year
low_data = data.pivot_table(index=[data["Date"].dt.year],values=["High","Open","Low","Close"],aggfunc="min")
display(avg_data)

# Displays the bar chart for above analysis
low_data.plot(kind="bar",width=0.8)
plt.xlabel("Price (in $US)", fontsize = 15)
plt.ylabel("Year", fontsize = 15)
plt.title("Lowest Price of Ethereum", fontsize = 15)
plt.show()
# Out:
#             Close         High          Low         Open
# Date
# 2016    11.142660    11.557340    10.709731    11.157744
# 2017   220.337370   230.076685   206.164137   218.340959
# 2018   481.328575   501.888740   458.714932   482.989562
# 2019   180.992986   186.272685   175.172712   180.998822
# 2020   307.296776   315.490164   295.880765   305.653033
# 2021  2638.993606  2730.595667  2517.787970  2629.085667

# %%
# %matplotlib inline
# Displays the data and bar chart of average opening, closing, highest and lowest price of ethereum for every year
avg_data = data.pivot_table(index=[data["Date"].dt.year],values=["High","Open","Low","Close"],aggfunc="mean")
display(avg_data)

# Displays the bar chart for above analysis
avg_data.plot(kind="bar",width=0.8)
plt.xlabel("Price (in $US)", fontsize = 15)
plt.ylabel("Year", fontsize = 15)
plt.title("Average Price of Ethereum", fontsize = 15)
plt.show()
# Out:
#             Close         High          Low         Open
# Date
# 2016    11.142660    11.557340    10.709731    11.157744
# 2017   220.337370   230.076685   206.164137   218.340959
# 2018   481.328575   501.888740   458.714932   482.989562
# 2019   180.992986   186.272685   175.172712   180.998822
# 2020   307.296776   315.490164   295.880765   305.653033
# 2021  2638.993606  2730.595667  2517.787970  2629.085667
